# %%
import os
import torch
import tqdm
import numpy as np
from multiprocessing import Pool
from data_utils.prob_vol_data_utils import ProbVolDataset
from utils.localization_utils import finalize_localization

# Hardcoded Configuration
CONFIG = {
    "dataset_dir": "/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full",
    "prob_vol_save_dir": "/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full",
    "prob_vol_path": "/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/prob_vols",
    "L": 0,
    "start_scene": 0,
    "end_scene": 3000,
    "weight_combinations": [
        [1.0, 0.0],  # Only depth
        [0.9, 0.1],  # Weighted combination
        [0.5, 0.5],  # Equal combination
    ],
}

# Global variables for multiprocessing
dataset = None


def calculate_sample_accs(prob_vol_pred_depth, prob_vol_pred_semantic, weight_combinations, ref_pose, device):
    sample_accs = []

    for depth_weight, semantic_weight in weight_combinations:
        # Combine volumes
        min_shape = [min(d, s) for d, s in zip(prob_vol_pred_depth.shape, prob_vol_pred_semantic.shape)]
        prob_vol_pred_depth_sliced = prob_vol_pred_depth[tuple(slice(0, min_shape[i]) for i in range(len(min_shape)))]
        prob_vol_pred_semantic_sliced = prob_vol_pred_semantic[tuple(slice(0, min_shape[i]) for i in range(len(min_shape)))]
        combined_pred = depth_weight * prob_vol_pred_depth_sliced + semantic_weight * prob_vol_pred_semantic_sliced

        # Localize and calculate accuracy
        _, _, _, pose_pred = finalize_localization(combined_pred)
        pose_pred = torch.tensor(pose_pred, device=device, dtype=torch.float32)
        pose_pred[:2] = pose_pred[:2] / 10  # Scale poses
        acc_pred = torch.norm(pose_pred[:2] - ref_pose[:2], p=2).item()

        sample_accs.append(acc_pred)

    return sample_accs


def process_data_idx(data_idx):
    global dataset
    device = torch.device("cpu")

    if dataset is None:
        dataset = ProbVolDataset(
            dataset_dir=CONFIG["dataset_dir"],
            scene_names=[f"scene_{str(i).zfill(5)}" for i in range(CONFIG["start_scene"], CONFIG["end_scene"] + 1)],
            L=CONFIG["L"],
            prob_vol_path=CONFIG["prob_vol_path"],
            acc_only=False,
        )

    data = dataset[data_idx]
    ref_pose = torch.tensor(data["ref_pose"], device=device, dtype=torch.float32)
    prob_vol_pred_depth = data['prob_vol_depth'].to(device)
    prob_vol_pred_semantic = data['prob_vol_semantic'].to(device)

    return calculate_sample_accs(
        prob_vol_pred_depth,
        prob_vol_pred_semantic,
        CONFIG["weight_combinations"],
        ref_pose,
        device,
    )


def generate_summary():
    weight_combinations = CONFIG["weight_combinations"]
    dataset = ProbVolDataset(
        dataset_dir=CONFIG["dataset_dir"],
        scene_names=[f"scene_{str(i).zfill(5)}" for i in range(CONFIG["start_scene"], CONFIG["end_scene"] + 1)],
        L=CONFIG["L"],
        prob_vol_path=CONFIG["prob_vol_path"],
        acc_only=False,
    )
    total_scenes = CONFIG["end_scene"] - CONFIG["start_scene"] + 1
    total_images = len(dataset)

    num_processes = os.cpu_count() -5

    with Pool(processes=num_processes) as pool:
        results = list(tqdm.tqdm(pool.imap(process_data_idx, range(total_images)), total=total_images, desc="Processing Data"))

    # Consolidate results for each weight combination
    accs_by_weights = list(zip(*results))

    less_than_counts = {threshold: [0] * len(weight_combinations) for threshold in ["0.1m", "0.5m", "1m"]}

    # Default combination indices
    default_idx = weight_combinations.index([0.5, 0.5])
    default_accs = accs_by_weights[default_idx]

    ref_idx_1_0 = weight_combinations.index([1.0, 0.0])
    ref_accs_1_0 = accs_by_weights[ref_idx_1_0]

    below_1m_better_0_5 = {threshold: [0] * len(weight_combinations) for threshold in ["0.1m", "0.5m", "1m"]}
    below_1m_better_1_0 = {threshold: [0] * len(weight_combinations) for threshold in ["0.1m", "0.5m", "1m"]}

    for idx, accs in enumerate(accs_by_weights):
        for acc, default_acc, ref_acc in zip(accs, default_accs, ref_accs_1_0):
            # General thresholds
            if acc < 0.1:
                less_than_counts["0.1m"][idx] += 1
            if acc < 0.5:
                less_than_counts["0.5m"][idx] += 1
            if acc < 1.0:
                less_than_counts["1m"][idx] += 1

            # Accuracy lower than 1m
            if acc < 1.0:
                # Compare with (0.5, 0.5)
                if acc < default_acc - 0.1:
                    below_1m_better_0_5["0.1m"][idx] += 1
                if acc < default_acc - 0.5:
                    below_1m_better_0_5["0.5m"][idx] += 1
                if acc < default_acc - 1.0:
                    below_1m_better_0_5["1m"][idx] += 1

                # Compare with (1.0, 0.0)
                if acc < ref_acc - 0.1:
                    below_1m_better_1_0["0.1m"][idx] += 1
                if acc < ref_acc - 0.5:
                    below_1m_better_1_0["0.5m"][idx] += 1
                if acc < ref_acc - 1.0:
                    below_1m_better_1_0["1m"][idx] += 1

    # Print total counts
    print(f"Total number of scenes: {total_scenes}")
    print(f"Total number of images: {total_images}\n")

    # Original Table: General Counts
    print("Summary of Results:\n")
    header = (
        f"{'Weights':<30} {'Count < 0.1m':<25} {'Count < 0.5m':<25} {'Count < 1m':<25} "
    )
    divider = "-" * len(header)
    print(header)
    print(divider)

    for idx, (depth_weight, semantic_weight) in enumerate(weight_combinations):
        weights_str = f"Depth={depth_weight}, Semantic={semantic_weight}"
        count_lt_01 = less_than_counts["0.1m"][idx]
        count_lt_05 = less_than_counts["0.5m"][idx]
        count_lt_1 = less_than_counts["1m"][idx]

        print(
            f"{weights_str:<30} {count_lt_01} ({count_lt_01 / total_images * 100:.2f}%)                 {count_lt_05} ({count_lt_05 / total_images * 100:.2f}%)                 {count_lt_1} ({count_lt_1 / total_images * 100:.2f}%)"
        )

    # Table 1: Below 1m and better than (0.5, 0.5)
    print("\nResults: Below 1m and Better than (0.5, 0.5):\n")
    header = (
        f"{'Weights':<30} {'Better by 0.1m':<30} {'Better by 0.5m':<30} {'Better by 1m':<30}"
    )
    divider = "-" * len(header)
    print(header)
    print(divider)

    for idx, (depth_weight, semantic_weight) in enumerate(weight_combinations):
        weights_str = f"Depth={depth_weight}, Semantic={semantic_weight}"
        better_by_01 = below_1m_better_0_5["0.1m"][idx]
        better_by_05 = below_1m_better_0_5["0.5m"][idx]
        better_by_1 = below_1m_better_0_5["1m"][idx]

        print(
            f"{weights_str:<30} {better_by_01} ({better_by_01 / total_images * 100:.2f}%)                    {better_by_05} ({better_by_05 / total_images * 100:.2f}%)                    {better_by_1} ({better_by_1 / total_images * 100:.2f}%)"
        )

    # Table 2: Below 1m and better than (1.0, 0.0)
    print("\nResults: Below 1m and Better than (1.0, 0.0):\n")
    print(header)
    print(divider)

    for idx, (depth_weight, semantic_weight) in enumerate(weight_combinations):
        weights_str = f"Depth={depth_weight}, Semantic={semantic_weight}"
        better_by_01 = below_1m_better_1_0["0.1m"][idx]
        better_by_05 = below_1m_better_1_0["0.5m"][idx]
        better_by_1 = below_1m_better_1_0["1m"][idx]

        print(
            f"{weights_str:<30} {better_by_01} ({better_by_01 / total_images * 100:.2f}%)                    {better_by_05} ({better_by_05 / total_images * 100:.2f}%)                    {better_by_1} ({better_by_1 / total_images * 100:.2f}%)"
        )


if __name__ == "__main__":
    generate_summary()
# Out:
#   7%|▋         | 197/3001 [00:00<00:02, 1021.90it/s]
# Scene scene_46 has floorplan_semantic.png with dimensions 3444x1454, skipping this scene.
# Missing prediction files for scene scene_103, image 0. Skipping this scene.
# Missing files for scene scene_144: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_144/poses.txt'], skipping this scene.
#  17%|█▋        | 509/3001 [00:00<00:02, 856.33it/s]
# Scene scene_360 has floorplan_semantic.png with dimensions 1492x3715, skipping this scene.
# Missing prediction files for scene scene_500, image 0. Skipping this scene.
#  32%|███▏      | 950/3001 [00:00<00:01, 1052.41it/s]
# Scene scene_765 has floorplan_semantic.png with dimensions 3240x2440, skipping this scene.
# Scene scene_978 has floorplan_semantic.png with dimensions 3325x999, skipping this scene.
#  38%|███▊      | 1152/3001 [00:01<00:02, 871.41it/s]
# Scene scene_1045 has floorplan_semantic.png with dimensions 3070x1428, skipping this scene.
# Scene scene_1078 has floorplan_semantic.png with dimensions 3357x2248, skipping this scene.
# Missing files for scene scene_1155: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1155/poses.txt'], skipping this scene.
#  45%|████▌     | 1352/3001 [00:01<00:01, 892.74it/s]
# Missing files for scene scene_1192: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1192/poses.txt'], skipping this scene.
#  61%|██████▏   | 1841/3001 [00:01<00:00, 1399.56it/s]
# Missing files for scene scene_1600: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1600/poses.txt'], skipping this scene.
# Missing files for scene scene_1601: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1601/poses.txt'], skipping this scene.
# Missing files for scene scene_1602: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1602/poses.txt'], skipping this scene.
# Missing files for scene scene_1603: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1603/poses.txt'], skipping this scene.
# Missing files for scene scene_1604: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1604/poses.txt'], skipping this scene.
# Missing files for scene scene_1605: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1605/poses.txt'], skipping this scene.
# Missing files for scene scene_1606: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1606/poses.txt'], skipping this scene.
# Missing files for scene scene_1607: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1607/poses.txt'], skipping this scene.
# Missing files for scene scene_1608: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1608/poses.txt'], skipping this scene.
# Missing files for scene scene_1609: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1609/poses.txt'], skipping this scene.
# Missing files for scene scene_1610: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1610/poses.txt'], skipping this scene.
# Missing files for scene scene_1611: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1611/poses.txt'], skipping this scene.
# Missing files for scene scene_1612: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1612/poses.txt'], skipping this scene.
# Missing files for scene scene_1613: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1613/poses.txt'], skipping this scene.
# Missing files for scene scene_1614: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1614/poses.txt'], skipping this scene.
# Missing files for scene scene_1615: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1615/poses.txt'], skipping this scene.
# Missing files for scene scene_1616: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1616/poses.txt'], skipping this scene.
# Missing files for scene scene_1617: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1617/poses.txt'], skipping this scene.
# Missing files for scene scene_1618: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1618/poses.txt'], skipping this scene.
# Missing files for scene scene_1619: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1619/poses.txt'], skipping this scene.
# Missing files for scene scene_1620: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1620/poses.txt'], skipping this scene.
# Missing files for scene scene_1621: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1621/poses.txt'], skipping this scene.
# Missing files for scene scene_1622: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1622/poses.txt'], skipping this scene.
# Missing files for scene scene_1623: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1623/poses.txt'], skipping this scene.
# Missing files for scene scene_1624: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1624/poses.txt'], skipping this scene.
# Missing files for scene scene_1625: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1625/poses.txt'], skipping this scene.
# Missing files for scene scene_1626: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1626/poses.txt'], skipping this scene.
# Missing files for scene scene_1627: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1627/poses.txt'], skipping this scene.
# Missing files for scene scene_1628: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1628/poses.txt'], skipping this scene.
# Missing files for scene scene_1629: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1629/poses.txt'], skipping this scene.
# Missing files for scene scene_1630: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1630/poses.txt'], skipping this scene.
# Missing files for scene scene_1631: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1631/poses.txt'], skipping this scene.
# Missing files for scene scene_1632: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1632/poses.txt'], skipping this scene.
# Missing files for scene scene_1633: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1633/poses.txt'], skipping this scene.
# Missing files for scene scene_1634: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1634/poses.txt'], skipping this scene.
# Missing files for scene scene_1635: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1635/poses.txt'], skipping this scene.
# Missing files for scene scene_1636: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1636/poses.txt'], skipping this scene.
# Missing files for scene scene_1637: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1637/poses.txt'], skipping this scene.
# Missing files for scene scene_1638: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1638/poses.txt'], skipping this scene.
# Missing files for scene scene_1639: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1639/poses.txt'], skipping this scene.
# Missing files for scene scene_1640: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1640/poses.txt'], skipping this scene.
# Missing files for scene scene_1641: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1641/poses.txt'], skipping this scene.
# Missing files for scene scene_1642: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1642/poses.txt'], skipping this scene.
# Missing files for scene scene_1643: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1643/poses.txt'], skipping this scene.
# Missing files for scene scene_1644: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1644/poses.txt'], skipping this scene.
# Missing files for scene scene_1645: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1645/poses.txt'], skipping this scene.
# Missing files for scene scene_1646: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1646/poses.txt'], skipping this scene.
# Missing files for scene scene_1647: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1647/poses.txt'], skipping this scene.
# Missing files for scene scene_1648: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1648/poses.txt'], skipping this scene.
# Missing files for scene scene_1649: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1649/poses.txt'], skipping this scene.
# Missing files for scene scene_1650: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1650/poses.txt'], skipping this scene.
# Missing files for scene scene_1651: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1651/poses.txt'], skipping this scene.
# Missing files for scene scene_1652: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1652/poses.txt'], skipping this scene.
# Missing files for scene scene_1653: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1653/poses.txt'], skipping this scene.
# Missing files for scene scene_1654: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1654/poses.txt'], skipping this scene.
# Missing files for scene scene_1655: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1655/poses.txt'], skipping this scene.
# Missing files for scene scene_1656: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1656/poses.txt'], skipping this scene.
# Missing files for scene scene_1657: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1657/poses.txt'], skipping this scene.
# Missing files for scene scene_1658: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1658/poses.txt'], skipping this scene.
# Missing files for scene scene_1659: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1659/poses.txt'], skipping this scene.
# Missing files for scene scene_1660: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1660/poses.txt'], skipping this scene.
# Missing files for scene scene_1661: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1661/poses.txt'], skipping this scene.
# Missing files for scene scene_1662: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1662/poses.txt'], skipping this scene.
# Missing files for scene scene_1663: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1663/poses.txt'], skipping this scene.
# Missing files for scene scene_1664: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1664/poses.txt'], skipping this scene.
# Missing files for scene scene_1665: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1665/poses.txt'], skipping this scene.
# Missing files for scene scene_1666: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1666/poses.txt'], skipping this scene.
# Missing files for scene scene_1667: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1667/poses.txt'], skipping this scene.
# Missing files for scene scene_1668: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1668/poses.txt'], skipping this scene.
# Missing files for scene scene_1669: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1669/poses.txt'], skipping this scene.
# Missing files for scene scene_1670: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1670/poses.txt'], skipping this scene.
# Missing files for scene scene_1671: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1671/poses.txt'], skipping this scene.
# Missing files for scene scene_1672: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1672/poses.txt'], skipping this scene.
# Missing files for scene scene_1673: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1673/poses.txt'], skipping this scene.
# Missing files for scene scene_1674: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1674/poses.txt'], skipping this scene.
# Missing files for scene scene_1675: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1675/poses.txt'], skipping this scene.
# Missing files for scene scene_1676: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1676/poses.txt'], skipping this scene.
# Missing files for scene scene_1677: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1677/poses.txt'], skipping this scene.
# Missing files for scene scene_1678: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1678/poses.txt'], skipping this scene.
# Missing files for scene scene_1679: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1679/poses.txt'], skipping this scene.
# Missing files for scene scene_1680: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1680/poses.txt'], skipping this scene.
# Missing files for scene scene_1681: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1681/poses.txt'], skipping this scene.
# Missing files for scene scene_1682: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1682/poses.txt'], skipping this scene.
# Missing files for scene scene_1683: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1683/poses.txt'], skipping this scene.
# Missing files for scene scene_1684: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1684/poses.txt'], skipping this scene.
# Missing files for scene scene_1685: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1685/poses.txt'], skipping this scene.
# Missing files for scene scene_1686: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1686/poses.txt'], skipping this scene.
# Missing files for scene scene_1687: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1687/poses.txt'], skipping this scene.
# Missing files for scene scene_1688: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1688/poses.txt'], skipping this scene.
# Missing files for scene scene_1689: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1689/poses.txt'], skipping this scene.
# Missing files for scene scene_1690: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1690/poses.txt'], skipping this scene.
# Missing files for scene scene_1691: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1691/poses.txt'], skipping this scene.
# Missing files for scene scene_1692: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1692/poses.txt'], skipping this scene.
# Missing files for scene scene_1693: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1693/poses.txt'], skipping this scene.
# Missing files for scene scene_1694: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1694/poses.txt'], skipping this scene.
# Missing files for scene scene_1695: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1695/poses.txt'], skipping this scene.
# Missing files for scene scene_1696: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1696/poses.txt'], skipping this scene.
# Missing files for scene scene_1697: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1697/poses.txt'], skipping this scene.
# Missing files for scene scene_1698: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1698/poses.txt'], skipping this scene.
# Missing files for scene scene_1699: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1699/poses.txt'], skipping this scene.
# Missing files for scene scene_1700: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1700/poses.txt'], skipping this scene.
# Missing files for scene scene_1701: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1701/poses.txt'], skipping this scene.
# Missing files for scene scene_1702: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1702/poses.txt'], skipping this scene.
# Missing files for scene scene_1703: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1703/poses.txt'], skipping this scene.
# Missing files for scene scene_1704: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1704/poses.txt'], skipping this scene.
# Missing files for scene scene_1705: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1705/poses.txt'], skipping this scene.
# Missing files for scene scene_1706: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1706/poses.txt'], skipping this scene.
# Missing files for scene scene_1707: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1707/poses.txt'], skipping this scene.
# Missing files for scene scene_1708: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1708/poses.txt'], skipping this scene.
# Missing files for scene scene_1709: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1709/poses.txt'], skipping this scene.
# Missing files for scene scene_1710: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1710/poses.txt'], skipping this scene.
# Missing files for scene scene_1711: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1711/poses.txt'], skipping this scene.
# Missing files for scene scene_1712: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1712/poses.txt'], skipping this scene.
# Missing files for scene scene_1713: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1713/poses.txt'], skipping this scene.
# Missing files for scene scene_1714: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1714/poses.txt'], skipping this scene.
# Missing files for scene scene_1715: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1715/poses.txt'], skipping this scene.
# Missing files for scene scene_1716: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1716/poses.txt'], skipping this scene.
# Missing files for scene scene_1717: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1717/poses.txt'], skipping this scene.
# Missing files for scene scene_1718: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1718/poses.txt'], skipping this scene.
# Missing files for scene scene_1719: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1719/poses.txt'], skipping this scene.
# Missing files for scene scene_1720: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1720/poses.txt'], skipping this scene.
# Missing files for scene scene_1721: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1721/poses.txt'], skipping this scene.
# Missing files for scene scene_1722: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1722/poses.txt'], skipping this scene.
# Missing files for scene scene_1723: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1723/poses.txt'], skipping this scene.
# Missing files for scene scene_1724: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1724/poses.txt'], skipping this scene.
# Missing files for scene scene_1725: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1725/poses.txt'], skipping this scene.
# Missing files for scene scene_1726: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1726/poses.txt'], skipping this scene.
# Missing files for scene scene_1727: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1727/poses.txt'], skipping this scene.
# Missing files for scene scene_1728: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1728/poses.txt'], skipping this scene.
# Missing files for scene scene_1729: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1729/poses.txt'], skipping this scene.
# Missing files for scene scene_1730: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1730/poses.txt'], skipping this scene.
# Missing files for scene scene_1731: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1731/poses.txt'], skipping this scene.
# Missing files for scene scene_1732: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1732/poses.txt'], skipping this scene.
# Missing files for scene scene_1733: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1733/poses.txt'], skipping this scene.
# Missing files for scene scene_1734: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1734/poses.txt'], skipping this scene.
# Missing files for scene scene_1735: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1735/poses.txt'], skipping this scene.
# Missing files for scene scene_1736: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1736/poses.txt'], skipping this scene.
# Missing files for scene scene_1737: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1737/poses.txt'], skipping this scene.
# Missing files for scene scene_1738: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1738/poses.txt'], skipping this scene.
# Missing files for scene scene_1739: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1739/poses.txt'], skipping this scene.
# Missing files for scene scene_1740: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1740/poses.txt'], skipping this scene.
# Missing files for scene scene_1741: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1741/poses.txt'], skipping this scene.
# Missing files for scene scene_1742: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1742/poses.txt'], skipping this scene.
# Missing files for scene scene_1743: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1743/poses.txt'], skipping this scene.
# Missing files for scene scene_1744: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1744/poses.txt'], skipping this scene.
# Missing files for scene scene_1745: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1745/poses.txt'], skipping this scene.
# Missing files for scene scene_1746: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1746/poses.txt'], skipping this scene.
# Missing files for scene scene_1747: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1747/poses.txt'], skipping this scene.
# Missing files for scene scene_1748: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1748/poses.txt'], skipping this scene.
# Missing files for scene scene_1749: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1749/poses.txt'], skipping this scene.
# Missing files for scene scene_1750: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1750/poses.txt'], skipping this scene.
# Missing files for scene scene_1751: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1751/poses.txt'], skipping this scene.
# Missing files for scene scene_1752: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1752/poses.txt'], skipping this scene.
# Missing files for scene scene_1753: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1753/poses.txt'], skipping this scene.
# Missing files for scene scene_1754: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1754/poses.txt'], skipping this scene.
# Missing files for scene scene_1755: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1755/poses.txt'], skipping this scene.
# Missing files for scene scene_1756: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1756/poses.txt'], skipping this scene.
# Missing files for scene scene_1757: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1757/poses.txt'], skipping this scene.
# Missing files for scene scene_1758: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1758/poses.txt'], skipping this scene.
# Missing files for scene scene_1759: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1759/poses.txt'], skipping this scene.
# Missing files for scene scene_1760: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1760/poses.txt'], skipping this scene.
# Missing files for scene scene_1761: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1761/poses.txt'], skipping this scene.
# Missing files for scene scene_1762: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1762/poses.txt'], skipping this scene.
# Missing files for scene scene_1763: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1763/poses.txt'], skipping this scene.
# Missing files for scene scene_1764: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1764/poses.txt'], skipping this scene.
# Missing files for scene scene_1765: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1765/poses.txt'], skipping this scene.
# Missing files for scene scene_1766: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1766/poses.txt'], skipping this scene.
# Missing files for scene scene_1767: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1767/poses.txt'], skipping this scene.
# Missing files for scene scene_1768: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1768/poses.txt'], skipping this scene.
# Missing files for scene scene_1769: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1769/poses.txt'], skipping this scene.
# Missing files for scene scene_1770: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1770/poses.txt'], skipping this scene.
# Missing files for scene scene_1771: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1771/poses.txt'], skipping this scene.
# Missing files for scene scene_1772: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1772/poses.txt'], skipping this scene.
# Missing files for scene scene_1773: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1773/poses.txt'], skipping this scene.
# Missing files for scene scene_1774: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1774/poses.txt'], skipping this scene.
# Missing files for scene scene_1775: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1775/poses.txt'], skipping this scene.
# Missing files for scene scene_1776: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1776/poses.txt'], skipping this scene.
# Missing files for scene scene_1777: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1777/poses.txt'], skipping this scene.
# Missing files for scene scene_1778: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1778/poses.txt'], skipping this scene.
# Missing files for scene scene_1779: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1779/poses.txt'], skipping this scene.
# Missing files for scene scene_1780: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1780/poses.txt'], skipping this scene.
# Missing files for scene scene_1781: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1781/poses.txt'], skipping this scene.
# Missing files for scene scene_1782: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1782/poses.txt'], skipping this scene.
# Missing files for scene scene_1783: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1783/poses.txt'], skipping this scene.
# Missing files for scene scene_1784: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1784/poses.txt'], skipping this scene.
# Missing files for scene scene_1785: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1785/poses.txt'], skipping this scene.
# Missing files for scene scene_1786: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1786/poses.txt'], skipping this scene.
# Missing files for scene scene_1787: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1787/poses.txt'], skipping this scene.
# Missing files for scene scene_1788: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1788/poses.txt'], skipping this scene.
# Missing files for scene scene_1789: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1789/poses.txt'], skipping this scene.
# Missing files for scene scene_1790: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1790/poses.txt'], skipping this scene.
# Missing files for scene scene_1791: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1791/poses.txt'], skipping this scene.
# Missing files for scene scene_1792: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1792/poses.txt'], skipping this scene.
# Missing files for scene scene_1793: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1793/poses.txt'], skipping this scene.
# Missing files for scene scene_1794: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1794/poses.txt'], skipping this scene.
# Missing files for scene scene_1795: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1795/poses.txt'], skipping this scene.
# Missing files for scene scene_1796: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1796/poses.txt'], skipping this scene.
# Missing files for scene scene_1797: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1797/poses.txt'], skipping this scene.
# Missing files for scene scene_1798: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1798/poses.txt'], skipping this scene.
# Missing files for scene scene_1799: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1799/poses.txt'], skipping this scene.
# Missing files for scene scene_1816: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1816/poses.txt'], skipping this scene.
# Missing files for scene scene_1852: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_1852/poses.txt'], skipping this scene.
#  74%|███████▍  | 2228/3001 [00:02<00:00, 1016.50it/s]
# Missing prediction files for scene scene_2026, image 0. Skipping this scene.
# Scene scene_2051 has floorplan_semantic.png with dimensions 4016x1516, skipping this scene.
# Missing prediction files for scene scene_2098, image 0. Skipping this scene.
# Missing files for scene scene_2119: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_2119/poses.txt'], skipping this scene.
# Scene scene_2208 has floorplan_semantic.png with dimensions 2028x3035, skipping this scene.
#  85%|████████▌ | 2558/3001 [00:02<00:00, 978.22it/s]
# Missing files for scene scene_2401: ['/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/scene_2401/poses.txt'], skipping this scene.
# 100%|██████████| 3001/3001 [00:03<00:00, 976.95it/s]
# Missing prediction files for scene scene_2800, image 0. Skipping this scene.
# Number of scenes after filtering: 2781

# %%
import argparse
import os
import numpy as np
import torch
import tqdm
import yaml
from attrdict import AttrDict
import cv2
import torch.nn as nn
from PIL import Image

# Import your models
from modules.mono.depth_net_pl import depth_net_pl
from modules.semantic.semantic_net_pl import semantic_net_pl

# Import your dataset
from data_utils.data_utils import GridSeqDataset
import torch.nn.functional as F

# Import helper functions from utils
from utils.localization_utils import (
    get_ray_from_depth,
    get_ray_from_semantics,
    localize,
    finalize_localization,
)
from utils.data_loader_helper import load_scene_data

# Torch DataLoader
from torch.utils.data import DataLoader


def evaluate_combined_model(
    depth_net,
    semantic_net,
    desdfs,
    semantics,
    test_set,
    gt_poses,
    maps,
    device,
    valid_scene_names,
    config,  
):
    improved_cases = {"rays_before": [], "rays_after": [], "accuracies": []}
    degraded_cases = {"rays_before": [], "rays_after": [], "accuracies": []}

    for data_idx in tqdm.tqdm(range(len(test_set))):
        data = test_set[data_idx]
        scene_idx = np.sum(data_idx >= np.array(test_set.scene_start_idx)) - 1
        scene = test_set.scene_names[scene_idx]
        if 'floor' not in scene:
            scene_number = int(scene.split("_")[1])
            scene = f"scene_{scene_number}"
        
        if not scene in valid_scene_names:
            continue
        idx_within_scene = data_idx - test_set.scene_start_idx[scene_idx]

        desdf = desdfs[scene]
        semantic = semantics[scene]
        ref_pose_map = gt_poses[scene][idx_within_scene * (config["L"] + 1) + config["L"], :]

        # Predict depth
        ref_img_torch = torch.tensor(data["ref_img"], device=device).unsqueeze(0)
        pred_depths, _, _ = depth_net.encoder(ref_img_torch, None)
        pred_depths = pred_depths.squeeze(0).detach().cpu().numpy()
        pred_rays_depth = get_ray_from_depth(pred_depths, V=config["V"], F_W=config["F_W"])

        # Predict semantics
        _, _, prob = semantic_net.encoder(ref_img_torch, None)
        prob_squeezed = prob.squeeze(dim=0)
        sampled_indices = torch.multinomial(
            prob_squeezed, num_samples=1, replacement=True
        )
        sampled_indices = sampled_indices.squeeze(dim=1)
        sampled_indices_np = sampled_indices.cpu().numpy()

        # Rays before and after processing
        rays_before_get_ray = sampled_indices_np.copy()
        pred_rays_semantic = get_ray_from_semantics(sampled_indices_np, V=config["V"], F_W=config["F_W"])
        rays_after_get_ray = pred_rays_semantic.copy()

        # Depth localization
        prob_vol_pred_depth, _, _, _ = localize(
            torch.tensor(desdf["desdf"]),
            torch.tensor(pred_rays_depth, device="cpu"),
            return_np=False,
        )
        _, _, _, pose_pred_depth = finalize_localization(prob_vol_pred_depth)
        pose_pred_depth = torch.tensor(pose_pred_depth, device=device, dtype=torch.float32)
        pose_pred_depth[:2] = pose_pred_depth[:2] / 10
        acc_depth = torch.norm(pose_pred_depth[:2] - torch.tensor(ref_pose_map[:2], device=device), p=2).item()

        # Combined localization
        prob_vol_pred_semantic, _, _, _ = localize(
            torch.tensor(semantic["desdf"]),
            torch.tensor(pred_rays_semantic, device="cpu"),
            return_np=False,
        )
        combined_prob_vol_pred = 0.5 * prob_vol_pred_depth + 0.5 * prob_vol_pred_semantic
        _, _, _, pose_pred_combined = finalize_localization(combined_prob_vol_pred)
        pose_pred_combined = torch.tensor(pose_pred_combined, device=device, dtype=torch.float32)
        pose_pred_combined[:2] = pose_pred_combined[:2] / 10
        acc_combined = torch.norm(pose_pred_combined[:2] - torch.tensor(ref_pose_map[:2], device=device), p=2).item()

        # Check for improvement or degradation
        if acc_combined <= acc_depth:
            improved_cases["rays_before"].append(rays_before_get_ray)
            improved_cases["rays_after"].append(rays_after_get_ray)
            improved_cases["accuracies"].append((data_idx, acc_depth, acc_combined))
        elif acc_combined > acc_depth:
            degraded_cases["rays_before"].append(rays_before_get_ray)
            degraded_cases["rays_after"].append(rays_after_get_ray)
            degraded_cases["accuracies"].append((data_idx, acc_depth, acc_combined))

    # Print all results
    print("\nEvaluation Complete.")

    print("\nImproved Accuracy Cases:")
    print("All Rays Before Get Ray:")
    for rays in improved_cases["rays_before"]:
        print(rays)

    print("\nAll Rays After Get Ray:")
    for rays in improved_cases["rays_after"]:
        print(rays)

    print("\nImproved Accuracy Details:")
    for idx, acc_depth, acc_combined in improved_cases["accuracies"]:
        print(f"Image {idx}: Acc Depth = {acc_depth}, Acc Combined = {acc_combined}")

    print("\nDegraded Accuracy Cases:")
    print("All Rays Before Get Ray:")
    for rays in degraded_cases["rays_before"]:
        print(rays)

    print("\nAll Rays After Get Ray:")
    for rays in degraded_cases["rays_after"]:
        print(rays)

    print("\nDegraded Accuracy Details:")
    for idx, acc_depth, acc_combined in degraded_cases["accuracies"]:
        print(f"Image {idx}: Acc Depth = {acc_depth}, Acc Combined = {acc_combined}")


def evaluate_observation(config, device):
    dataset_dir = config["dataset_dir"]
    desdf_path = config["desdf_path"]
    log_dir_depth = config["log_dir_depth"]
    log_dir_semantic = config["log_dir_semantic"]
    split_file = config["split_file"]

    # Load dataset
    with open(split_file, "r") as f:
        split = AttrDict(yaml.safe_load(f))

    test_set = GridSeqDataset(
        dataset_dir,
        split.train[:config["num_of_scenes"]],
        L=config["L"],
    )

    depth_net = depth_net_pl.load_from_checkpoint(
        checkpoint_path=log_dir_depth,
        d_min=config["d_min"],
        d_max=config["d_max"],
        d_hyp=config["d_hyp"],
        D=config["D"],
    ).to(device)

    semantic_net = semantic_net_pl.load_from_checkpoint(
        checkpoint_path=log_dir_semantic,
        num_classes=config["num_classes"],
    ).to(device)

    desdfs, semantics, maps, gt_poses, valid_scene_names = load_scene_data(
        test_set, dataset_dir, desdf_path
    )

    evaluate_combined_model(
        depth_net,
        semantic_net,
        desdfs,
        semantics,
        test_set,
        gt_poses,
        maps,
        device,
        valid_scene_names,
        config=config,
    )


def main():
    # Hardcoded configuration
    config = {
        "dataset_dir": "/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full",
        "desdf_path": "/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/desdf",
        "log_dir_depth": "/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/modules/Final_wights/depth/final_depth_model_checkpoint.ckpt",
        "log_dir_semantic": "/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/modules/Final_wights/semantic/final_semantic_model_checkpoint.ckpt",
        "split_file": "/datadrive2/CRM.AI.Research/TeamFolders/Email/repo_yuval/FloorPlan/Semantic_Floor_plan_localization/data/test_data_set_full/structured3d_perspective_full/split.yaml",
        "L": 0,
        "D": 128,
        "d_min": 0.1,
        "d_max": 15.0,
        "d_hyp": -0.2,
        "F_W": 0.59587643422,
        "V": 7,
        "num_classes": 4,
        "num_of_scenes": 1,
    }

    # Set device
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    # Run evaluation
    evaluate_observation(config, device)


if __name__ == "__main__":
    main()
